# %%
import pandas as pd

# %%
df = pd.read_csv("11.7_NYC_Inspections_CLEANED.csv")

# %%
df = df[['CAMIS', 'DBA', 'BORO', 'STREET', 'ZIPCODE', 'CUISINE DESCRIPTION', 'INSPECTION DATE', 'ACTION', 'VIOLATION DESCRIPTION', 'CRITICAL FLAG']]
df
# Out:
#            CAMIS                 DBA       BORO                STREET  \
# 0       40931569         JOE'S PIZZA      Bronx       east 233 street
# 1       50071977              DUNKIN      Bronx       east 138 street
# 2       50000923    DI FARA PIZZERIA   Brooklyn              avenue j
# 3       50113199           PIG BEACH     Queens             36 street
# 4       50098376        BAGEL MARKET  Manhattan      lexington avenue
# ...          ...                 ...        ...                   ...
# 284432  50119040      B'AIRES BAKERY     Queens      roosevelt avenue
# 284433  40375929       VILLA FIORITA   Brooklyn             18 avenue
# 284434  50149838  XING FU TANG KTOWN  Manhattan              5 avenue
# 284435  41711527              DUNKIN  Manhattan           pine street
# 284436  40383284    VERDI RESTAURANT     Queens  cross island parkway
#
#         ZIPCODE       CUISINE DESCRIPTION       INSPECTION DATE  \
# ...

# %%
df.sample(frac = 0.75, random_state = 477)
# Out:
#            CAMIS                                         DBA       BORO  \
# 122205  50171238  SUSHI & SIPS CAFE @ STUDENT UNION BUILDING     Queens
# 266328  40785023                                 SAHARA EAST  Manhattan
# 114454  50136989                       HOT SPOT GRILL & JERK      Bronx
# 166319  50088048                                TRIPLE DEUCE      Bronx
# 55266   50146361                      CARAVAN UYGHUR CUISINE  Manhattan
# ...          ...                                         ...        ...
# 264889  50011657                            THE SABIENG THAI  Manhattan
# 89588   41172734                                    JUNIOR'S  Manhattan
# 109357  50018845                           PASTICCERIA ROCCO   Brooklyn
# 88980   41376398                               MASPETH PIZZA     Queens
# 98538   50108323                                         KFC   Brooklyn
#
#                    STREET  ZIPCODE CUISINE DESCRIPTION       INSPECTION DATE  \
# ...

# %%
df.to_csv('11.10_NYC_Inspections_CLEANSAMPLE.csv', index = False)
