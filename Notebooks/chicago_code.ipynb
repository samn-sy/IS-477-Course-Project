# %%
import pandas as pd
import numpy as np
import os

# %%
script_dir = os.getcwd()
chicago_path = os.path.join(script_dir, '..', 'Data', 'Original Datasets', '11.7_Chicago_Food_Inspections.csv')

chi_df = pd.read_csv(chicago_path)

# %%
chi_df.head()
# Out:
#    Inspection ID                              DBA Name  \
# 0        2626662  FIELD MUSEUM KIOSK AT O'HARE AIRPORT
# 1        2626671                VIDA SALUD Y BIENESTAR
# 2        2626566                              KOMOREBI
# 3        2626626            LITTLE LEADERS OF TOMORROS
# 4        2626572        SCHWAB REHAB HOSPITAL&CARE NET
#
#                          AKA Name  License #          Facility Type  \
# 0           FIELD MUSEUM (T1 B 8)  3052230.0                 Liquor
# 1          VIDA SALUD Y BIENESTAR  2134034.0          Grocery Store
# 2                        KOMOREBI  2501826.0             Restaurant
# 3      LITTLE LEADERS OF TOMORROS  2522839.0  Daycare (2 - 6 Years)
# 4  SCHWAB REHAB HOSPITAL&CARE NET  2205586.0               Hospital
#
#               Risk                Address     City State      Zip  \
# 0     Risk 3 (Low)      11601 W TOUHY AVE  CHICAGO    IL  60666.0
# 1  Risk 2 (Medium)         2600 W 47TH ST  CHICAGO    IL  60632.0
# 2    Risk 1 (High)   1324 N MILWAUKEE AVE  CHICAGO    IL  60622.0
# 3    Risk 1 (High)     301 N MAYFIELD AVE  CHICAGO    IL  60644.0
# 4    Risk 1 (High)  1401 S CALIFORNIA AVE  CHICAGO    IL  60608.0
#
#   Inspection Date Inspection Type Results  \
# 0      11/06/2025         License    Pass
# 1      11/06/2025         Canvass    Pass
# 2      11/05/2025         Canvass    Fail
# 3      11/05/2025         Canvass    Fail
# 4      11/05/2025         Canvass    Pass
#
#                                           Violations   Latitude  Longitude  \
# 0                                                NaN  42.008751 -87.906874
# 1  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  41.808469 -87.689388
# 2  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  41.905710 -87.670391
# 3  38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...  41.885696 -87.771829
# 4  51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICE...        NaN        NaN
#
#                                   Location
# 0  (42.00875076599798, -87.90687413400109)
# 1  (41.808468524155444, -87.6893881621428)
# 2  (41.90570956925753, -87.67039084096871)
# 3  (41.885696044521445, -87.7718290036689)
# 4                                      NaN
