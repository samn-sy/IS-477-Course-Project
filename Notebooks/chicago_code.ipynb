# %%
import pandas as pd
import numpy as np
import os

# %%
script_dir = os.getcwd()
# chicago_path = os.path.join(script_dir, '..', 'Data', 'Original Datasets', '11.7_Chicago_Food_Inspections.csv')
# newYork_path = os.path.join(script_dir, '..', 'Data', 'Original Datasets', '11.7_New_York_City_Inspections.csv')

# chicago_cleaned_path = os.path.join(script_dir, '..', 'Data', 'Cleaned Datasets', 'Chicago_Inspections_Data', '11-7-Chicago-Food-Inspections.csv')
newYork_cleaned_path = os.path.join(script_dir, '..', 'Data', 'Cleaned Datasets', 'NYC_Inspections_Data', '11.12_NYC_Inspections_CLEANED.csv')

# chi_df = pd.read_csv(chicago_path)
# ny_df = pd.read_csv(newYork_path)

# chi_cleandf = pd.read_csv(chicago_cleaned_path)
ny_cleandf = pd.read_csv(newYork_cleaned_path)

# %%
# chi_df.sample(frac = .25, random_state = 477).to_csv('11.7_Chicago_Food_Inspections_Reduced.csv', index=False)
# ny_df.sample(frac = .57, random_state = 477).to_csv('11.7_New_York_City_Inspections_Reduced.csv', index=False)

# chi_cleandf.sample(frac = .27, random_state = 477).to_csv('11.7_Chicago_Food_Inspections_Cleaned_Reduced.csv', index=False)
ny_cleandf.sample(frac = .57, random_state = 477).to_csv('11.12_NYC_Inspections_CLEANED_Reduced.csv', index=False)
