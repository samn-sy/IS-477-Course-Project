# %%
import pandas as pd
import numpy as np
import os

# %%
script_dir = os.getcwd()
chicago_path = os.path.join(script_dir, '..', 'Data', 'Cleaned Datasets', 'Chicago_Inspections_Data', '11.7_Chicago_Food_Inspections_Cleaned_Reduced.csv')
newYork_path = os.path.join(script_dir, '..', 'Data', 'Cleaned Datasets', 'NYC_Inspections_Data', '11.16_NYC_Inspections_Cleaned_Reduced.csv')

chicago = pd.read_csv(chicago_path)
nyc = pd.read_csv(newYork_path)

# %%
chicago['Zip'] = chicago['Zip'].astype('Int64')
chicago['License #'] = chicago['License #'].astype('Int64')

chicago['DBA Name'] = chicago['DBA Name'].str.upper()

chicago = chicago[["License #", "DBA Name", "Risk", "Address", "City", "State", "Zip", "Inspection Date", "Facility Type", "Violations", "Results"]]

chicago.head()
# Out:
#    License #                             DBA Name           Risk  \
# 0      20470              MARQUETTE NATIONAL BANK  Risk 1 (High)
# 1      26281           HENRY O. TANNER ELEMENTARY  Risk 1 (High)
# 2    2314919  CHICAGOLAND DELI INTERNATIONAL, INC  Risk 1 (High)
# 3    1649359                   CORNER BAKERY CAFE  Risk 1 (High)
# 4    1491413                    BURRITO BEACH # 8  Risk 1 (High)
#
#                    Address     City State    Zip       Inspection Date  \
# 0       6316 S WESTERN AVE  CHICAGO    IL  60636  2012-10-15T00:00:00Z
# 1             7350 S Evans  CHICAGO    IL  60619  2012-05-15T00:00:00Z
# 2  3956 N NARRAGANSETT AVE  CHICAGO    IL  60634  2023-04-17T00:00:00Z
# 3       360 N MICHIGAN AVE  CHICAGO    IL  60601  2012-09-17T00:00:00Z
# 4            200 E OHIO ST  CHICAGO    IL  60611  2020-03-05T00:00:00Z
#
#    Facility Type                                         Violations  \
# 0     Restaurant                                                NaN
# 1         School  14. PREVIOUS SERIOUS VIOLATION CORRECTED, 7-42...
# 2  Grocery Store  38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...
# 3     Restaurant  16. FOOD PROTECTED DURING STORAGE, PREPARATION...
# 4     Restaurant  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...
#
#               Results
# 0     Out of Business
# 1                Fail
# 2                Pass
# 3  Pass w/ Conditions
# 4                Pass

# %%
nyc["City"] = "NEW YORK CITY"
nyc["State"] = "NY"

nyc = nyc.rename(
    columns={"DBA": "DBA Name", "BORO": "Boro", "STREET": "Street", "ZIPCODE": "Zip", "CUISINE DESCRIPTION": "Cuisine Description", "INSPECTION DATE": "Inspection Date", "VIOLATION DESCRIPTION": "Violations", "CRITICAL FLAG": "Critical Flag"}
)

nyc = nyc[["CAMIS", "DBA Name", "Boro", "Critical Flag", "Street", "City", "State", "Zip", "Cuisine Description", "Inspection Date", "Violations"]]
nyc['Violations'] = nyc['Violations'].str.upper()

nyc.head()
# Out:
#       CAMIS                                    DBA Name       Boro  \
# 0  50171238  SUSHI & SIPS CAFE @ STUDENT UNION BUILDING     Queens
# 1  40785023                                 SAHARA EAST  Manhattan
# 2  50136989                       HOT SPOT GRILL & JERK      Bronx
# 3  50088048                                TRIPLE DEUCE      Bronx
# 4  50146361                      CARAVAN UYGHUR CUISINE  Manhattan
#
#   Critical Flag             Street           City State    Zip  \
# 0      Critical          56 AVENUE  NEW YORK CITY    NY  11364
# 1      Critical           1 AVENUE  NEW YORK CITY    NY  10009
# 2      Critical  WHITE PLAINS ROAD  NEW YORK CITY    NY  10470
# 3      Critical        BOSTON ROAD  NEW YORK CITY    NY  10466
# 4      Critical      BEAVER STREET  NEW YORK CITY    NY  10004
#
#   Cuisine Description       Inspection Date  \
# 0  Asian/Asian Fusion  2025-08-27T00:00:00Z
# 1      Middle Eastern  2023-10-03T00:00:00Z
# 2           Caribbean  2023-06-01T00:00:00Z
# 3           Caribbean  2025-10-16T00:00:00Z
# 4  Asian/Asian Fusion  2025-10-02T00:00:00Z
#
#                                           Violations
# 0  FOOD CONTACT SURFACE NOT PROPERLY WASHED, RINS...
# 1  FOOD, SUPPLIES, OR EQUIPMENT NOT PROTECTED FRO...
# 2  PROPERLY SCALED AND CALIBRATED THERMOMETER OR ...
# 3  FILTH FLIES OR FOOD/REFUSE/SEWAGE ASSOCIATED W...
# 4  FOOD PROTECTION CERTIFICATE (FPC) NOT HELD BY ...

# %% [markdown]
# ## Optional: Save each cleaned reduced dataset

# %%
# chicago.to_csv(os.path.join(script_dir, '..', 'Data', 'Data Integration', '11.16_Chicago_Inspections_Reduced.csv'), index=False)
# nyc.to_csv(os.path.join(script_dir, '..', 'Data', 'Data Integration', '11.16_NYC_Inspections_Reduced.csv'), index=False)

# %%
final_df = pd.concat([nyc, chicago], ignore_index=True)
final_df.index = range(1, len(final_df) + 1)
final_df['RecordID'] = final_df.index

final_df = final_df[['RecordID', 'DBA Name', 'CAMIS', 'License #', 'Address', 'Street', 'City', 'Boro', 'State', 'Zip', 'Inspection Date', 'Risk', 'Critical Flag', 'Facility Type', 'Cuisine Description', 'Violations', 'Results']]
final_df['CAMIS'] = final_df['CAMIS'].astype('Int64')
final_df
# Out:
#         RecordID                                    DBA Name     CAMIS  \
# 1              1  SUSHI & SIPS CAFE @ STUDENT UNION BUILDING  50171238
# 2              2                                 SAHARA EAST  40785023
# 3              3                       HOT SPOT GRILL & JERK  50136989
# 4              4                                TRIPLE DEUCE  50088048
# 5              5                      CARAVAN UYGHUR CUISINE  50146361
# ...          ...                                         ...       ...
# 223225    223225                             MARGIES CANDIES      <NA>
# 223226    223226  THE GRILLING CATERING AND DELIVERY COMPANY      <NA>
# 223227    223227                           POCKETS HYDE PARK      <NA>
# 223228    223228                               THE PLAY ROOM      <NA>
# 223229    223229                                       MIKOS      <NA>
#
#         License #              Address             Street           City  \
# 1            <NA>                  NaN          56 AVENUE  NEW YORK CITY
# 2            <NA>                  NaN           1 AVENUE  NEW YORK CITY
# 3            <NA>                  NaN  WHITE PLAINS ROAD  NEW YORK CITY
# 4            <NA>                  NaN        BOSTON ROAD  NEW YORK CITY
# 5            <NA>                  NaN      BEAVER STREET  NEW YORK CITY
# ...           ...                  ...                ...            ...
# 223225    1622713  1813 W MONTROSE AVE                NaN        CHICAGO
# 223226    2120233        302 E 75TH ST                NaN        CHICAGO
# 223227    2153361       1309 E 53RD ST                NaN        CHICAGO
# 223228    1697530   7958 W BELMONT AVE                NaN        CHICAGO
# 223229    1045159    3000 W LYNDALE ST                NaN        CHICAGO
#
#              Boro State    Zip       Inspection Date             Risk  \
# 1          Queens    NY  11364  2025-08-27T00:00:00Z              NaN
# 2       Manhattan    NY  10009  2023-10-03T00:00:00Z              NaN
# 3           Bronx    NY  10470  2023-06-01T00:00:00Z              NaN
# 4           Bronx    NY  10466  2025-10-16T00:00:00Z              NaN
# 5       Manhattan    NY  10004  2025-10-02T00:00:00Z              NaN
# ...           ...   ...    ...                   ...              ...
# 223225        NaN    IL  60613  2013-10-22T00:00:00Z    Risk 1 (High)
# 223226        NaN    IL  60619  2011-09-27T00:00:00Z    Risk 1 (High)
# 223227        NaN    IL  60615  2013-10-09T00:00:00Z  Risk 2 (Medium)
# 223228        NaN    IL  60634  2014-07-16T00:00:00Z    Risk 1 (High)
# 223229        NaN    IL  60647  2014-09-10T00:00:00Z  Risk 2 (Medium)
#
#        Critical Flag Facility Type Cuisine Description  \
# 1           Critical           NaN  Asian/Asian Fusion
# 2           Critical           NaN      Middle Eastern
# 3           Critical           NaN           Caribbean
# 4           Critical           NaN           Caribbean
# 5           Critical           NaN  Asian/Asian Fusion
# ...              ...           ...                 ...
# 223225           NaN    Restaurant                 NaN
# 223226           NaN      Catering                 NaN
# 223227           NaN    Restaurant                 NaN
# 223228           NaN    Restaurant                 NaN
# 223229           NaN    Restaurant                 NaN
#
#                                                Violations Results
# 1       FOOD CONTACT SURFACE NOT PROPERLY WASHED, RINS...     NaN
# 2       FOOD, SUPPLIES, OR EQUIPMENT NOT PROTECTED FRO...     NaN
# 3       PROPERLY SCALED AND CALIBRATED THERMOMETER OR ...     NaN
# 4       FILTH FLIES OR FOOD/REFUSE/SEWAGE ASSOCIATED W...     NaN
# 5       FOOD PROTECTION CERTIFICATE (FPC) NOT HELD BY ...     NaN
# ...                                                   ...     ...
# 223225  16. FOOD PROTECTED DURING STORAGE, PREPARATION...    Fail
# 223226                                                NaN    Fail
# 223227  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...    Pass
# 223228  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...    Pass
# 223229  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...    Pass
#
# [223229 rows x 17 columns]

# %% [markdown]
# ## Optional: Save to CSV

# %%
# final_df.to_csv(os.path.join(script_dir, '..', 'Data', 'Data Integration', '11.16_Inspections.csv'), index=False)

# %% [markdown]
# ___

# %%
# Reducing for Github Repo
final_red = final_df.sample(frac = .75, random_state=477)
final_red
# Out:
#         RecordID                                     DBA Name     CAMIS  \
# 174415    174415                              THEATER WIT NFP      <NA>
# 182294    182294                       WEST TOWN DAYCARE ,LLC      <NA>
# 171418    171418  CHILDREN'S HOME AND AID SOCIETY OF ILLINOIS      <NA>
# 73133      73133                                 MCLOUGHLIN'S  40587835
# 21130      21130                                          REX  50125902
# ...          ...                                          ...       ...
# 132983    132983                 TAQUERIA Y FONDA LA MEXICANA  41486399
# 5143        5143                         WING HING RESTAURANT  50123658
# 174317    174317                    SMART LEARNING CENTER LLC      <NA>
# 24208      24208                                      TACOMBI  50072348
# 1206        1206                                  CARVEL 2848  40959012
#
#         License #                 Address            Street           City  \
# 174415    2037878      1229 W BELMONT AVE               NaN        CHICAGO
# 182294    2570038        2751 W CORTEZ ST               NaN        CHICAGO
# 171418    2215528          1701 W 63RD ST               NaN        CHICAGO
# 73133        <NA>                     NaN          BROADWAY  NEW YORK CITY
# 21130        <NA>                     NaN         10 AVENUE  NEW YORK CITY
# ...           ...                     ...               ...            ...
# 132983       <NA>                     NaN  AMSTERDAM AVENUE  NEW YORK CITY
# 5143         <NA>                     NaN     ROGERS AVENUE  NEW YORK CITY
# 174317    2231589  2839-2841 S ARCHER AVE               NaN        CHICAGO
# 24208        <NA>                     NaN          5 AVENUE  NEW YORK CITY
# 1206         <NA>                     NaN         86 STREET  NEW YORK CITY
#
#              Boro State    Zip       Inspection Date             Risk  \
# 174415        NaN    IL  60657  2010-07-01T00:00:00Z     Risk 3 (Low)
# 182294        NaN    IL  60622  2019-07-25T00:00:00Z    Risk 1 (High)
# 171418        NaN    IL  60636  2023-04-21T00:00:00Z    Risk 1 (High)
# 73133      Queens    NY  11106  2024-05-23T00:00:00Z              NaN
# 21130   Manhattan    NY  10019  2024-11-21T00:00:00Z              NaN
# ...           ...   ...    ...                   ...              ...
# 132983  Manhattan    NY  10025  2023-02-08T00:00:00Z              NaN
# 5143     Brooklyn    NY  11225  2023-04-06T00:00:00Z              NaN
# 174317        NaN    IL  60608  2025-04-18T00:00:00Z  Risk 2 (Medium)
# 24208   Manhattan    NY  10118  2025-04-23T00:00:00Z              NaN
# 1206     Brooklyn    NY  11214  2023-09-20T00:00:00Z              NaN
#
#        Critical Flag                      Facility Type Cuisine Description  \
# 174415           NaN                         Restaurant                 NaN
# 182294           NaN  1023 CHILDERN'S SERVICES FACILITY                 NaN
# 171418           NaN    Daycare Above and Under 2 Years                 NaN
# 73133       Critical                                NaN               Irish
# 21130       Critical                                NaN          Coffee/Tea
# ...              ...                                ...                 ...
# 132983  Not Critical                                NaN             Mexican
# 5143        Critical                                NaN             Chinese
# 174317           NaN               after school program                 NaN
# 24208   Not Critical                                NaN             Tex-Mex
# 1206        Critical                                NaN     Frozen Desserts
#
#                                                Violations   Results
# 174415  21. * CERTIFIED FOOD MANAGER ON SITE WHEN POTE...      Fail
# 182294                                                NaN      Pass
# 171418                                                NaN  No Entry
# 73133   FOOD CONTACT SURFACE NOT PROPERLY WASHED, RINS...       NaN
# 21130   EVIDENCE OF RATS OR LIVE RATS IN ESTABLISHMENT...       NaN
# ...                                                   ...       ...
# 132983  NON-FOOD CONTACT SURFACE OR EQUIPMENT MADE OF ...       NaN
# 5143    COLD TCS FOOD ITEM HELD ABOVE 41 °F; SMOKED OR...       NaN
# 174317                                                NaN      Pass
# 24208                         THAWING PROCEDURE IMPROPER.       NaN
# 1206    NO HAND WASHING FACILITY IN OR ADJACENT TO TOI...       NaN
#
# [167422 rows x 17 columns]

# %% [markdown]
# ## Optional: Save Reduced file to CSV

# %%
# final_red.to_csv(os.path.join(script_dir, '..', 'Data', 'Data Integration', '11.16_Inspections_Reduced.csv'), index=False)
