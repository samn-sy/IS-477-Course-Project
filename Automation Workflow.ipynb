# %%
! snakemake --cores 1
# Out:
# Assuming unrestricted shared filesystem usage.
# host: e60f99cdf329
# Building DAG of jobs...
# Using shell: /usr/bin/bash
# Provided cores: 1 (use --cores to define parallelism)
# Rules claiming more threads will be scaled down.
# Job stats:
# job              count
# -------------  -------
# run_all              1
# visualization        1
# total                2
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Mon Dec  8 03:00:45 2025]
# localrule visualization:
#     input: Data/Data Integration/11.16_Chicago_Inspections_Reduced.csv, Data/Data Integration/11.16_NYC_Inspections_Reduced.csv, Data/Data Integration/11.16_Inspections_Reduced.csv
#     output: Visualizations/passing_inspections_year.png, Visualizations/passing_inspections_yearmonth.png
#     jobid: 1
#     reason: Missing output files: Visualizations/passing_inspections_year.png, Visualizations/passing_inspections_yearmonth.png
#     resources: tmpdir=/tmp
# Business Not Located Results: 0.03%
# ...

# %%
! python Scripts/dag.py
from IPython.display import Image
Image(filename='dag.png')
